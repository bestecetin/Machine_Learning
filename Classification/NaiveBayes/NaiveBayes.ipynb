# %%
from IPython.display import Image
Image(filename='foto/nv.png')

# %% [markdown]
# -Similarity range: biz belirliyoruz. Belirlediğim range içerisinde 3 math 1 adet fizik toplam 4 adet data point var.
# - Marginal likelihood'u hesaplarken 4/11 yapıyoruz buradaki 4 similarity range'i veriyor.
# - P(Math|X)= (3/16)*(6/11) / (4/11) = 3/4 = %75 yani %75 oraninda math ögretmeni demek.
# - P(Fizik|X)= (1/5) * (5/11) / (4/11) = 1/4 = %25 yani %25 oranında fizik ögretmeni.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data= pd.read_csv('data/data.csv')

# %%
data.drop(["id","Unnamed: 32"], axis=1, inplace= True)
data.tail()
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
M = data[data.diagnosis == "M"]
B = data[data.diagnosis == "B"]

# %%
plt.scatter(M.radius_mean, M.texture_mean, color="red", label="kotu", alpha=0.3)
plt.scatter(B.radius_mean, B.texture_mean, color="green", label="iyi", alpha=0.3)
plt.ylabel("texture_mean")
plt.xlabel("radius_mean")
plt.legend()
plt.show()

# %%
data.diagnosis= [1 if each == "M" else 0 for each in data.diagnosis]
y = data.diagnosis.values
x_data = data.drop(["diagnosis"], axis=1)

# %%
#normalization
x = (x_data - np.min(x_data))/(np.max(x_data)-np.min(x_data))

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=42)

# %%
#Naive Bayes
from sklearn. import SVC
svm=SVC(random_state=42)
svm.fit(x_train, y_train)
# Out:
# SVC(random_state=42)

# %%
print("accuracy:", svm.score(x_test , y_test))
# Out:
# accuracy: 0.9824561403508771
