# %%
from IPython.display import Image
Image(filename='foto/dt.png')

# %% [markdown]
# - classification yapmak icin gerekli splitler ayriliyor.
# - splitler mor ve mavi siniflari ayirmak icin en iyi cizgiyi cekiyor.
# - splitlere göre karar agacimiz sekilleniyor.

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('data/data.csv')

# %%
data.drop(["id","Unnamed: 32"],axis=1,inplace = True) #datadaki gereksiz sutunlar silindi.

# %%
data.diagnosis = [ 1 if each == "M" else 0 for each in data.diagnosis]
#sklearn kutuphanesi stringlerle islem yapamadigi icin sayisal verilere cevirdik.

# %%
y = data.diagnosis.values
x_data = data.drop(["diagnosis"],axis=1)

# %%
#normalization
x = (x_data - np.min(x_data))/(np.max(x_data)-np.min(x_data))

# %%
#train ve test split
from sklearn.model_selection import train_test_split
x_train, x_test,y_train, y_test = train_test_split(x,y,test_size = 0.15,random_state = 42)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("decision tree score: ", dt.score(x_test,y_test))
# Out:
# decision tree score:  0.9069767441860465
